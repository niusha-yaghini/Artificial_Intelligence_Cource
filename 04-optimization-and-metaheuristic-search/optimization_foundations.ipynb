# %% [markdown]
# <h1> Optimization Foundation </h1>

# %% [markdown]
# <h3> Part 1 — What is Optimization? </h3>
# Optimization is the process of finding the best solution among </br>feasible alternatives according to an objective function.</br>
#
#
# <h3> Part 2 — Problem Formulation </h3>
# Includes:</br>
# Decision Variables</br>
# Objective Function</br>
# Constraints</br>
#
#
# <h3> Part 3 — Search Space </h3>
# Continuous Space</br>
# Discrete Space</br>
# Combinatorial Space</br>
#
#
# <h3> Part 4 — Objective Function </h3>
#
#
# <h3> Part 5 — Optimization Types </h3>
# Minimization</br>
# Maximization</br>
#
# <h3> Part 6 — Local vs Global Optimum </h3>
# Diagrams
#
#
# <h3> Part 7 — Exploration vs Exploitation </h3>
# The most important part.
#
#
# <h3> Part 8 — Exact vs Approximate Optimization </h3>
# Comparison:</br>
# Exact Metaheuristic</br>
# Guaranteed optimum Near-optimal</br>
# Expensive Faster</br>
# Complete search Intelligent search
#
#
# <h3> Part 9 — Metaheuristic Overview </h3>
