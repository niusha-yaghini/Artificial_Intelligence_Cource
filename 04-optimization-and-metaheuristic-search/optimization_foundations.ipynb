# %% [markdown]
# <h1> Optimization Foundation </h1>

# %% [markdown]
# **This Notebook answers the question:**
#
# **What kind of problem do we call Optimization, and what common framework do all the algorithms in this chapter work on?**
#
# **That is, a common conceptual layer.**

# %% [markdown]
# **The mental structure is common to all optimization algorithms.**
#
# That is, before we say "How to solve it?", we need to know "What are we solving?"

# %% [markdown]
# <h3> Part 1 — What is Optimization? </h3>
# Optimization is the process of finding the best solution among </br>feasible alternatives according to an objective function.</br>
#
#
# <h3> Part 2 — Problem Formulation </h3>
# Includes:</br>
# Decision Variables</br>
# Objective Function</br>
# Constraints</br>
# Search Space
#
#
# <h3> Part 3 — Optimization Landscape </h3>
# Local optimum</br>
# Global optimum</br>
# Convex / Non-convex</br>
# Multimodal functions</br>
#
#
# <h3> Part 4 — Optimization Strategies </h3>
# Local Search</br>
# Population-based Search</br>
#
#
# <h3> Part 5 — Evaluation Concepts </h3>
# Fitness / Objective Evaluation </br>
# Convergence </br>
#
#
# <h3> Part 6 — Exploration vs Exploitation </h3>
