# %%
from src.games import TicTacToe

# %% [markdown]
# <h1> Tic-Tac-Toe Game </h1> <h3> (Game Environment Only) </h3>

# %%
game = TicTacToe()

game

# %%
state = game.initial_state()

state
# Out:
# ((' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '), 'X')

# %%
game.actions(state)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
next_state = game.result(
    state,
    4
)

next_state
# Out:
# ((' ', ' ', ' ', ' ', 'X', ' ', ' ', ' ', ' '), 'O')
